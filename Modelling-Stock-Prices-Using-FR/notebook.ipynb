# %% [markdown]
# <a href="https://colab.research.google.com/github/ml-nest/passion_projects/blob/main/Modelling-Stock-Prices-Using-FR/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Mounting GDrive
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/github/Modelling-stock-price-using-FR/
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/github/Modelling-stock-price-using-FR

# %% [markdown]
# # Scrapping financial data from screener.in

# %%
from urllib.request import urlopen
import web_scrapping as ws
import pandas as pd
import numpy as np

# %%
link = "https://www.screener.in/company/IOC/consolidated/"

page = urlopen(link)

html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %% [markdown]
# ## Quaterly Results

# %%
headings_value, temp, rest = ws.getting_headers(html, "Quarterly Results", "Profit & Loss")

qr_index = ['Sales', 'Expenses', 'Operating Profit', 'OPM %', 'Other Income', 'Interest', 
            'Depreciation', 'Profit before tax', 'Tax %', 'Net Profit', 'EPS in Rs']

quarter_results = pd.DataFrame(columns = headings_value)

for i in qr_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    quarter_results.loc[i] = ws.string_to_float(values)

# %%
quarter_results
# Out:
#                     Mar 2018  Jun 2018  ...  Sep 2020   Dec 2020
# Sales              116956.00  128707.0  ...   81704.0  101969.00
# Expenses           105539.00  115645.0  ...   71513.0   92176.00
# Operating Profit    11418.00   13062.0  ...   10192.0    9794.00
# OPM %                  10.00      10.0  ...      12.0      10.00
# Other Income          488.00     847.0  ...    1290.0    1235.00
# Interest             1344.00    1153.0  ...     320.0     734.00
# Depreciation         2134.00    1961.0  ...    2656.0    2723.00
# Profit before tax    8428.00   10795.0  ...    8506.0    7572.00
# Tax %                  33.00      34.0  ...      28.0      46.00
# Net Profit           5527.00    7092.0  ...    6026.0    4359.00
# EPS in Rs               5.69       7.3  ...       6.4       4.63
#
# [11 rows x 12 columns]

# %% [markdown]
# ## Profit Loss

# %%
headings_value, temp, rest = ws.getting_headers(rest, "Profit & Loss", "Balance Sheet")

pl_index = ['Sales', 'Expenses', 'Operating Profit', 'OPM %', 'Other Income', 'Interest', 
            'Depreciation', 'Profit before tax', 'Tax %', 'Net Profit', 'EPS in Rs', 'Dividend Payout %']

pl_results = pd.DataFrame(columns = headings_value)

for i in pl_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    pl_results.loc[i] = ws.string_to_float(values)

# %%
pl_results
# Out:
#                     Mar 2009   Mar 2010   Mar 2011   Mar 2012   Mar 2013  \
# Sales              288670.00  250046.00  309797.00  408923.00  461780.00
# Expenses           281875.00  236613.00  295154.00  389402.00  447887.00
# Operating Profit     6795.00   13433.00   14643.00   19521.00   13892.00
# OPM %                   2.00       5.00       5.00       5.00       3.00
# Other Income         4325.00    6948.00    3421.00   -4268.00    3468.00
# Interest             4282.00    1777.00    3017.00    5948.00    7164.00
# Depreciation         3189.00    3555.00    4933.00    5309.00    5692.00
# Profit before tax    3649.00   15049.00   10114.00    3995.00    4504.00
# Tax %                  34.00      27.00      20.00      -7.00      19.00
# Net Profit           2599.00   10713.00    7831.00    4226.00    4449.00
# EPS in Rs               2.73      11.03       8.06       4.35       4.58
# Dividend Payout %      36.00      30.00      30.00      30.00      36.00
#
# ...

# %% [markdown]
# ## Balance Sheet

# %%
headings_value, temp, rest = ws.getting_headers(rest, "Balance Sheet", "Cash Flows")

bs_index = ['Share Capital', 'Reserves', 'Borrowings', 'Other Liabilities', 'Total Liabilities', 'Fixed Assets', 
            'CWIP', 'Investments', 'Other Assets', 'Total Assets']

bs_results = pd.DataFrame(columns = headings_value)

for i in bs_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    bs_results.loc[i] = ws.string_to_float(values)

# %%
bs_results
# Out:
#                    Mar 2009  Mar 2010  Mar 2011  Mar 2012  Mar 2013  Mar 2014  \
# Share Capital        1214.0    2428.0    2428.0    2428.0    2428.0    2428.0
# Reserves            44290.0   50034.0   55147.0   57945.0   60608.0   65485.0
# Borrowings          47347.0   49472.0   57763.0   80015.0   89671.0   94916.0
# Other Liabilities   43627.0   52823.0   69263.0   79438.0   89171.0  103124.0
# Total Liabilities  136457.0  154758.0  184601.0  219827.0  241878.0  265953.0
# Fixed Assets        38453.0   45458.0   62681.0   64586.0   66707.0   69724.0
# CWIP                19169.0   22810.0   10866.0   15450.0   27240.0   38061.0
# Investments         31324.0   21430.0   18647.0   17588.0   17351.0   15895.0
# Other Assets        47511.0   65061.0   92407.0  122203.0  130580.0  142273.0
# Total Assets       136457.0  154758.0  184601.0  219827.0  241878.0  265953.0
#
#                    Mar 2015  Mar 2016  Mar 2017  Mar 2018  Mar 2019  Mar 2020  \
# ...

# %% [markdown]
# ## Cash Flows

# %%
headings_value, temp, rest = ws.getting_headers(rest, "Cash Flows", "Ratios")

cf_index = ['Cash from Operating Activity', 'Cash from Investing Activity', 'Cash from Financing Activity', 'Net Cash Flow']

cf_results = pd.DataFrame(columns = headings_value)

for i in cf_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    cf_results.loc[i] = ws.string_to_float(values)

# %%
cf_results
# Out:
#                               Mar 2009  Mar 2010  Mar 2011  Mar 2012  \
# Cash from Operating Activity  -21341.0   -1609.0    6819.0    -763.0
# Cash from Investing Activity   18337.0    3595.0   -8090.0  -13056.0
# Cash from Financing Activity    2949.0   -1392.0    1211.0   13103.0
# Net Cash Flow                    -55.0     593.0     -61.0    -716.0
#
#                               Mar 2013  Mar 2014  Mar 2015  Mar 2016  \
# Cash from Operating Activity    9340.0   24195.0   46092.0   25624.0
# Cash from Investing Activity   -9294.0  -18594.0  -10215.0  -13610.0
# Cash from Financing Activity     352.0   -3116.0  -38283.0  -11890.0
# Net Cash Flow                    398.0    2485.0   -2406.0     124.0
#
#                               Mar 2017  Mar 2018  Mar 2019  Mar 2020
# Cash from Operating Activity   28216.0   29115.0   12747.0    8653.0
# Cash from Investing Activity  -17684.0  -17119.0  -22569.0  -29097.0
# ...

# %% [markdown]
# ## Ratios

# %%
headings_value, temp, rest = ws.getting_headers(rest, "Ratios", "Shareholding Pattern")

ratio_index = ['ROCE %', 'Debtor Days', 'Inventory Turnover']

ratio_results = pd.DataFrame(columns = headings_value)

for i in ratio_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    ratio_results.loc[i] = ws.string_to_float(values)

# %%
ratio_results
# Out:
#                     Mar 2009  Mar 2010  Mar 2011  Mar 2012  Mar 2013  \
# ROCE %                 10.00     18.00     12.00     14.00      8.00
# Debtor Days             6.00      8.00      9.00     10.00     10.00
# Inventory Turnover      7.82      6.26      5.71      6.16      6.43
#
#                     Mar 2014  Mar 2015  Mar 2016  Mar 2017  Mar 2018  \
# ROCE %                  9.00      6.00     14.00     20.00     22.00
# Debtor Days             9.00      6.00      8.00      9.00      9.00
# Inventory Turnover      6.31      6.62      6.27      5.16      5.01
#
#                     Mar 2019  Mar 2020
# ROCE %                 16.00      5.00
# Debtor Days            11.00     10.00
# Inventory Turnover      6.06      5.82

# %% [markdown]
# ## Shareholding Pattern

# %%
headings_value, temp, rest = ws.getting_headers(rest, "Shareholding Pattern", "Documents")

sp_index = ['Promoters', 'FIIs', 'DIIs', 'Government', 'Public']

sp_results = pd.DataFrame(columns = headings_value)

for i in sp_index:
    values, temp = ws.func(temp, i, "td", headings_value)
    sp_results.loc[i] = ws.string_to_float(values)

# %%
sp_results
# Out:
#             Mar 2018  Jun 2018  Sep 2018  Dec 2018  Mar 2019  Jun 2019  \
# Promoters      56.98     56.75     56.75     54.06     52.18     52.18
# FIIs            6.16      5.85      5.98      5.60      7.04      7.66
# DIIs           10.33     11.18     11.05     13.47     13.72     13.13
# Government      0.11      0.11      0.11      0.11      0.11      0.11
# Public         26.43     26.10     26.11     26.76     26.95     26.91
#
#             Sep 2019  Dec 2019  Mar 2020  Jun 2020  Sep 2020  Dec 2020
# Promoters      51.50     51.50     51.50     51.50     51.50     51.50
# FIIs            7.23      7.64      7.19      6.33      6.07      5.83
# DIIs           14.25     13.79     13.40     13.85     13.37     13.54
# Government      0.11      0.11      0.11      0.11      0.11      0.11
# Public         26.91     26.95     27.80     28.20     28.95     29.02
