# %% [markdown]
# ![image.png](attachment:82c8de5d-31c0-499e-b872-5ca3d3487500.png)

# %% [markdown]
# This kernel is going to solve <font color="red"><b> Predict Future Sales with Advanced Regression Analysis</b></font>, a popular machine learning dataset for <b>Kaggler</b>.<br>
# I am going to share how I work with a dataset step by step  <b>from data preparation and data analysis to statistical tests and implementing machine learning models.</b> <br>
# I will also describe the model results along with other tips.<br>
# Let's get started.</div>
# <br>
# If you like this notebook or find this notebook helpful, Please feel free to <font color="red"><b>UPVOTE</b></font> and/or leave a comment.
#
# <div> <b>This notebook is always a work in progress. So, please stay tuned for more to come.</b></div>
#
#
# This notebook referenced the following.<br>
# https://www.kaggle.com/deinforcement/top-1-predict-future-sales-features-lightgbm<br>
# https://www.kaggle.com/werooring/top-3-5-lightgbm-with-feature-engineering<br>
# https://www.kaggle.com/dlarionov/feature-engineering-xgboost

# %% [markdown]
# # 1: Importing Necessary Libraries and datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

import seaborn as sns
import sys
import itertools
import gc

from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor

import csv
from collections import OrderedDict
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import datetime

# %%
cats = pd.read_csv('data/item_categories.csv')
items = pd.read_csv('data/items.csv')
train = pd.read_csv('data/sales_train.csv')
test = pd.read_csv('data/test.csv')
shops = pd.read_csv('data/shops.csv')

# %% [markdown]
# # 2. Data Preprocessing

# %%
# Change data type for date calculation
train["date"] = pd.to_datetime(train["date"], format="%d.%m.%Y")
# Merge some duplicate shops
# train["shop_id"] = train["shop_id"].replace({0: 57, 1: 58, 11: 10, 40: 39})
# Keep only shops that are in the test set
train = train.loc[train.shop_id.isin(test["shop_id"].unique()), :]
# Drop training items with extreme or negative prices or sales counts
train = train[(train["item_price"] > 0) & (train["item_price"] < 50000)]
train = train[(train["item_cnt_day"] > 0) & (train["item_cnt_day"] < 1000)]

# %%
shops['city'] = shops['shop_name'].apply(lambda x: x.split()[0])
shops.loc[shops['city'] =='!Якутск', 'city'] = 'Якутск'

# Create Label Encoder
label_encoder = LabelEncoder()
# City Feature Label Encoding 
shops['city'] = label_encoder.fit_transform(shops['city'])

# %%
# Create the date the product was first sold as a feature
items['first_sale_date'] = train.groupby('item_id').agg({'date_block_num': 'min'})['date_block_num']
# Refine null values in items table
items = items.apply(lambda x: x.fillna(x.median()) if x.dtype != "O" else x, axis=0)

# %%
cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['type_code'] = LabelEncoder().fit_transform(cats['type'])
# if subtype is nan then type
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['subtype_code'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','type_code', 'subtype_code']]

# %%
# Merge data
train = train.merge(shops, on='shop_id', how='left')
train = train.merge(items, on='item_id', how='left')
train = train.merge(cats, on='item_category_id', how='left')
test = test.merge(shops, on='shop_id', how='left')
test = test.merge(items, on='item_id', how='left')
test = test.merge(cats, on='item_category_id', how='left')

# %%
test["date_block_num"] = 34
test["date_block_num"] = test["date_block_num"].astype(np.int8)
test["shop_id"] = test.shop_id.astype(np.int8)
test["item_id"] = test.item_id.astype(np.int16)
test = test.drop(columns="ID")

# %%
df = pd.concat([train, test])

# %%
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

df = df.merge(group, on=['date_block_num','shop_id','item_id'], how='left')
df['item_cnt_month'] = (df['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))

df = df.drop(['date','shop_name','item_name','item_cnt_day'], axis=1)

# %%
def add_mean(df, idx_features):
    # Check base features
    assert (idx_features[0] == 'date_block_num') and \
           len(idx_features) in [2, 3]
    
    # Set derived feature name 
    if len(idx_features) == 2:
        feature_name = idx_features[1] + '_mean_sales'
    else:
        feature_name = idx_features[1] + '_' + idx_features[2] + '_mean_sales'
    
    # Get average monthly sales by grouping based on base features
    group = df.groupby(idx_features).agg({'item_cnt_month': 'mean'})
    group = group.reset_index()
    group = group.rename(columns={'item_cnt_month': feature_name})
    
    # Merge df with group based on idx_features
    df = df.merge(group, on=idx_features, how='left')
    
    return df

# %%
# Create monthly average sales derived features grouped by ['date_block_num', 'item_id']
df = add_mean(df=df, idx_features=['date_block_num', 'item_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'item_category_id']
df = add_mean(df=df, idx_features=['date_block_num', 'item_category_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'item_id', 'city']
df = add_mean(df=df, idx_features=['date_block_num', 'item_id', 'city'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id', 'item_category_id']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id', 'item_category_id'])

# Create monthly average sales derived features grouped by ['date_block_num', 'shop_id', 'subtype_code']
df = add_mean(df=df, idx_features=['date_block_num', 'shop_id', 'subtype_code'])

# %%
df.sort_values(['item_id', 'shop_id', 'date_block_num'])
# Out:
#          date_block_num  shop_id  item_id  item_price  city  item_category_id  \
# 1223183              15       55        1      4490.0    27                76
# 1223238              15       55        1      4490.0    27                76
# 1435939              18       55        1      4490.0    27                76
# 1513679              19       55        1      4490.0    27                76
# 1605383              20       55        1      4490.0    27                76
# ...                 ...      ...      ...         ...   ...               ...
# 41637                 0       12    22168       799.0     7                62
# 689918                8       12    22168       799.0     7                62
# 97744                 1       16    22168       799.0    10                62
# 90056                 1       42    22168       799.0    19                62
# 1175051              14       25    22169      4349.0    13                69
#
#          first_sale_date  type_code  subtype_code  item_cnt_month  \
# 1223183             15.0         15            31             2.0
# 1223238             15.0         15            31             2.0
# 1435939             15.0         15            31             1.0
# 1513679             15.0         15            31             1.0
# 1605383             15.0         15            31             1.0
# ...                  ...        ...           ...             ...
# 41637                0.0         14            28             1.0
# 689918               0.0         14            28             1.0
# 97744                0.0         14            28             1.0
# 90056                0.0         14            28             1.0
# 1175051             14.0         14            56             1.0
#
#          item_id_mean_sales  shop_id_mean_sales  item_category_id_mean_sales  \
# 1223183                 2.0            6.859375                     7.015625
# 1223238                 2.0            6.859375                     7.015625
# 1435939                 1.0            7.335938                     7.160156
# 1513679                 1.0            8.218750                     8.085938
# 1605383                 1.0            8.164062                     8.179688
# ...                     ...                 ...                          ...
# 41637                   1.0            4.074219                     2.955078
# 689918                  1.0            6.914062                     2.476562
# 97744                   1.0            3.427734                     2.683594
# 90056                   1.0            5.164062                     2.683594
# 1175051                 1.0            5.917969                     4.402344
#
#          item_id_city_mean_sales  shop_id_item_category_id_mean_sales  \
# 1223183                      2.0                             7.015625
# 1223238                      2.0                             7.015625
# 1435939                      1.0                             7.160156
# 1513679                      1.0                             8.085938
# 1605383                      1.0                             8.179688
# ...                          ...                                  ...
# 41637                        1.0                             2.199219
# 689918                       1.0                             1.000000
# 97744                        1.0                             2.626953
# 90056                        1.0                             3.208984
# 1175051                      1.0                             7.000000
#
#          shop_id_subtype_code_mean_sales
# 1223183                         7.015625
# 1223238                         7.015625
# 1435939                         7.160156
# 1513679                         8.085938
# 1605383                         8.179688
# ...                                  ...
# 41637                           2.199219
# 689918                          1.000000
# 97744                           2.626953
# 90056                           3.208984
# 1175051                         7.000000
#
# [2621276 rows x 16 columns]

# %%
# 
df['duration_after_first_sale'] = df['date_block_num'] - df['first_sale_date']

# month of the year
df['month'] = df['date_block_num']%12

# %%
# keep_from_month = 2  # The first couple of months are dropped because of distortions to their features (e.g. wrong item age)
valid_month = 33

valid = df.loc[df.date_block_num == valid_month, :]
train = df.loc[df.date_block_num < valid_month, :]
# train = train[train.date_block_num >= keep_from_month]
X_train = train.drop(columns="item_cnt_month")
y_train = train.item_cnt_month
X_valid = valid.drop(columns="item_cnt_month")
y_valid = valid.item_cnt_month
test = df.drop(columns="item_cnt_month").loc[df.date_block_num == 34, :]

# %%
model_lgb = LGBMRegressor(colsample_bytree=0.8,learning_rate=0.01, max_depth=8,
              min_child_weight=1, min_split_gain=0.0222415, n_estimators=35000,
              num_leaves=966, reg_alpha=0.04, reg_lambda=0.073,
              subsample=0.6)

# %%
start = datetime.datetime.now()
lgbm = model_lgb.fit(X_train, 
                     y_train,
                     eval_set = [(X_train, y_train), (X_valid, y_valid)],
                     eval_metric ='rmse',
                     early_stopping_rounds = 400,
                     verbose =True)
end = datetime.datetime.now()
end-start
# Out:
# [1]	training's rmse: 5.29721	training's l2: 28.0604	valid_1's rmse: 5.03232	valid_1's l2: 25.3242
# [2]	training's rmse: 5.24764	training's l2: 27.5377	valid_1's rmse: 4.9855	valid_1's l2: 24.8552
# [3]	training's rmse: 5.19846	training's l2: 27.024	valid_1's rmse: 4.93862	valid_1's l2: 24.39
# [4]	training's rmse: 5.14991	training's l2: 26.5216	valid_1's rmse: 4.89279	valid_1's l2: 23.9394
# [5]	training's rmse: 5.10709	training's l2: 26.0823	valid_1's rmse: 4.85264	valid_1's l2: 23.5481
# [6]	training's rmse: 5.05961	training's l2: 25.5996	valid_1's rmse: 4.80824	valid_1's l2: 23.1191
# [7]	training's rmse: 5.01262	training's l2: 25.1263	valid_1's rmse: 4.7637	valid_1's l2: 22.6928
# [8]	training's rmse: 4.96596	training's l2: 24.6608	valid_1's rmse: 4.7196	valid_1's l2: 22.2747
# [303]	training's rmse: 1.12731	training's l2: 1.27083	valid_1's rmse: 1.06877	valid_1's l2: 1.14228
# [304]	training's rmse: 1.12618	training's l2: 1.26829	valid_1's rmse: 1.06765	valid_1's l2: 1.13987
# [305]	training's rmse: 1.12508	training's l2: 1.26579	valid_1's rmse: 1.06666	valid_1's l2: 1.13777
# [306]	training's rmse: 1.12417	training's l2: 1.26375	valid_1's rmse: 1.06561	valid_1's l2: 1.13552
# [307]	training's rmse: 1.12309	training's l2: 1.26132	valid_1's rmse: 1.06449	valid_1's l2: 1.13313
# [308]	training's rmse: 1.12198	training's l2: 1.25884	valid_1's rmse: 1.06348	valid_1's l2: 1.13099
# [309]	training's rmse: 1.12092	training's l2: 1.25646	valid_1's rmse: 1.06263	valid_1's l2: 1.12919
# [310]	training's rmse: 1.11989	training's l2: 1.25415	valid_1's rmse: 1.06169	valid_1's l2: 1.12718
# [311]	training's rmse: 1.1188	training's l2: 1.2517	valid_1's rmse: 1.06073	valid_1's l2: 1.12514
# [312]	training's rmse: 1.11781	training's l2: 1.2495	valid_1's rmse: 1.05998	valid_1's l2: 1.12356
# [313]	training's rmse: 1.117	training's l2: 1.24769	valid_1's rmse: 1.05903	valid_1's l2: 1.12155
# [314]	training's rmse: 1.11599	training's l2: 1.24544	valid_1's rmse: 1.05818	valid_1's l2: 1.11974
# [315]	training's rmse: 1.11501	training's l2: 1.24324	valid_1's rmse: 1.05726	valid_1's l2: 1.11781
# [316]	training's rmse: 1.11406	training's l2: 1.24113	valid_1's rmse: 1.05628	valid_1's l2: 1.11574
# [317]	training's rmse: 1.11327	training's l2: 1.23936	valid_1's rmse: 1.05538	valid_1's l2: 1.11383
# [318]	training's rmse: 1.11254	training's l2: 1.23775	valid_1's rmse: 1.05453	valid_1's l2: 1.11204
# [319]	training's rmse: 1.11179	training's l2: 1.23607	valid_1's rmse: 1.05371	valid_1's l2: 1.11031
# [320]	training's rmse: 1.11089	training's l2: 1.23407	valid_1's rmse: 1.05293	valid_1's l2: 1.10865
# [321]	training's rmse: 1.10992	training's l2: 1.23191	valid_1's rmse: 1.05207	valid_1's l2: 1.10686
# [322]	training's rmse: 1.10902	training's l2: 1.22993	valid_1's rmse: 1.0513	valid_1's l2: 1.10522
# [323]	training's rmse: 1.1083	training's l2: 1.22834	valid_1's rmse: 1.05064	valid_1's l2: 1.10384
# [324]	training's rmse: 1.1074	training's l2: 1.22632	valid_1's rmse: 1.04986	valid_1's l2: 1.1022
# [325]	training's rmse: 1.10653	training's l2: 1.22442	valid_1's rmse: 1.04895	valid_1's l2: 1.10029
# [326]	training's rmse: 1.10567	training's l2: 1.22252	valid_1's rmse: 1.04823	valid_1's l2: 1.0988
# [327]	training's rmse: 1.10479	training's l2: 1.22057	valid_1's rmse: 1.04728	valid_1's l2: 1.09679
# [328]	training's rmse: 1.10397	training's l2: 1.21876	valid_1's rmse: 1.04648	valid_1's l2: 1.09513
# [329]	training's rmse: 1.10318	training's l2: 1.217	valid_1's rmse: 1.04569	valid_1's l2: 1.09347
# [330]	training's rmse: 1.10257	training's l2: 1.21567	valid_1's rmse: 1.04493	valid_1's l2: 1.09187
# [331]	training's rmse: 1.10177	training's l2: 1.21389	valid_1's rmse: 1.04405	valid_1's l2: 1.09005
# [332]	training's rmse: 1.10095	training's l2: 1.21209	valid_1's rmse: 1.04337	valid_1's l2: 1.08862
# [333]	training's rmse: 1.10034	training's l2: 1.21075	valid_1's rmse: 1.04261	valid_1's l2: 1.08704
# [334]	training's rmse: 1.09955	training's l2: 1.209	valid_1's rmse: 1.04184	valid_1's l2: 1.08544
# [335]	training's rmse: 1.09878	training's l2: 1.20732	valid_1's rmse: 1.04107	valid_1's l2: 1.08382
# [336]	training's rmse: 1.09807	training's l2: 1.20576	valid_1's rmse: 1.04054	valid_1's l2: 1.08272
# [337]	training's rmse: 1.09742	training's l2: 1.20433	valid_1's rmse: 1.03992	valid_1's l2: 1.08144
# [338]	training's rmse: 1.09674	training's l2: 1.20283	valid_1's rmse: 1.03918	valid_1's l2: 1.07989
# [339]	training's rmse: 1.096	training's l2: 1.20122	valid_1's rmse: 1.03844	valid_1's l2: 1.07836
# [340]	training's rmse: 1.09527	training's l2: 1.19961	valid_1's rmse: 1.03753	valid_1's l2: 1.07647
# [341]	training's rmse: 1.09463	training's l2: 1.19821	valid_1's rmse: 1.03685	valid_1's l2: 1.07506
# [342]	training's rmse: 1.0939	training's l2: 1.19662	valid_1's rmse: 1.03617	valid_1's l2: 1.07364
# [343]	training's rmse: 1.09326	training's l2: 1.19521	valid_1's rmse: 1.03563	valid_1's l2: 1.07253
# [344]	training's rmse: 1.09262	training's l2: 1.19382	valid_1's rmse: 1.03504	valid_1's l2: 1.0713
# [345]	training's rmse: 1.09197	training's l2: 1.19239	valid_1's rmse: 1.03442	valid_1's l2: 1.07002
# [346]	training's rmse: 1.0913	training's l2: 1.19094	valid_1's rmse: 1.03381	valid_1's l2: 1.06877
# [347]	training's rmse: 1.0908	training's l2: 1.18985	valid_1's rmse: 1.0333	valid_1's l2: 1.06771
# [348]	training's rmse: 1.09017	training's l2: 1.18847	valid_1's rmse: 1.0327	valid_1's l2: 1.06647
# [349]	training's rmse: 1.08951	training's l2: 1.18703	valid_1's rmse: 1.03203	valid_1's l2: 1.06508
# [350]	training's rmse: 1.08905	training's l2: 1.18604	valid_1's rmse: 1.03154	valid_1's l2: 1.06408
# [351]	training's rmse: 1.08851	training's l2: 1.18486	valid_1's rmse: 1.0311	valid_1's l2: 1.06316
# [352]	training's rmse: 1.08794	training's l2: 1.18362	valid_1's rmse: 1.03058	valid_1's l2: 1.06209
# [353]	training's rmse: 1.08753	training's l2: 1.18273	valid_1's rmse: 1.03013	valid_1's l2: 1.06116
# [354]	training's rmse: 1.08695	training's l2: 1.18145	valid_1's rmse: 1.0296	valid_1's l2: 1.06008
# [355]	training's rmse: 1.08636	training's l2: 1.18017	valid_1's rmse: 1.02912	valid_1's l2: 1.05908
# [356]	training's rmse: 1.0858	training's l2: 1.17896	valid_1's rmse: 1.02869	valid_1's l2: 1.05821
# [357]	training's rmse: 1.08524	training's l2: 1.17776	valid_1's rmse: 1.028	valid_1's l2: 1.05679
# [358]	training's rmse: 1.08478	training's l2: 1.17675	valid_1's rmse: 1.02733	valid_1's l2: 1.05541
# [359]	training's rmse: 1.08439	training's l2: 1.17591	valid_1's rmse: 1.02695	valid_1's l2: 1.05462
# [360]	training's rmse: 1.08387	training's l2: 1.17477	valid_1's rmse: 1.02653	valid_1's l2: 1.05377
# [361]	training's rmse: 1.08341	training's l2: 1.17377	valid_1's rmse: 1.02609	valid_1's l2: 1.05286
# [362]	training's rmse: 1.08297	training's l2: 1.17282	valid_1's rmse: 1.02549	valid_1's l2: 1.05164
# [363]	training's rmse: 1.08252	training's l2: 1.17185	valid_1's rmse: 1.02491	valid_1's l2: 1.05044
# [364]	training's rmse: 1.08201	training's l2: 1.17075	valid_1's rmse: 1.02444	valid_1's l2: 1.04947
# [365]	training's rmse: 1.0816	training's l2: 1.16986	valid_1's rmse: 1.02402	valid_1's l2: 1.04862
# [366]	training's rmse: 1.08119	training's l2: 1.16898	valid_1's rmse: 1.02359	valid_1's l2: 1.04773
# [367]	training's rmse: 1.08071	training's l2: 1.16794	valid_1's rmse: 1.02304	valid_1's l2: 1.0466
# [368]	training's rmse: 1.08012	training's l2: 1.16667	valid_1's rmse: 1.02252	valid_1's l2: 1.04554
# [369]	training's rmse: 1.07959	training's l2: 1.16552	valid_1's rmse: 1.02201	valid_1's l2: 1.0445
# [370]	training's rmse: 1.07914	training's l2: 1.16455	valid_1's rmse: 1.02148	valid_1's l2: 1.04343
# [371]	training's rmse: 1.07873	training's l2: 1.16365	valid_1's rmse: 1.02106	valid_1's l2: 1.04256
# [372]	training's rmse: 1.07827	training's l2: 1.16266	valid_1's rmse: 1.02056	valid_1's l2: 1.04155
# [373]	training's rmse: 1.07781	training's l2: 1.16166	valid_1's rmse: 1.02011	valid_1's l2: 1.04063
# [374]	training's rmse: 1.07737	training's l2: 1.16073	valid_1's rmse: 1.01968	valid_1's l2: 1.03975
# [375]	training's rmse: 1.077	training's l2: 1.15994	valid_1's rmse: 1.01932	valid_1's l2: 1.03901
# [376]	training's rmse: 1.0765	training's l2: 1.15886	valid_1's rmse: 1.01907	valid_1's l2: 1.0385
# [377]	training's rmse: 1.07606	training's l2: 1.1579	valid_1's rmse: 1.01873	valid_1's l2: 1.03781
# [378]	training's rmse: 1.0757	training's l2: 1.15714	valid_1's rmse: 1.01819	valid_1's l2: 1.03671
# [379]	training's rmse: 1.07524	training's l2: 1.15615	valid_1's rmse: 1.01763	valid_1's l2: 1.03558
# [380]	training's rmse: 1.07487	training's l2: 1.15535	valid_1's rmse: 1.0172	valid_1's l2: 1.0347
# [381]	training's rmse: 1.07443	training's l2: 1.15441	valid_1's rmse: 1.01683	valid_1's l2: 1.03395
# [382]	training's rmse: 1.07405	training's l2: 1.15359	valid_1's rmse: 1.01648	valid_1's l2: 1.03323
# [383]	training's rmse: 1.07356	training's l2: 1.15252	valid_1's rmse: 1.01614	valid_1's l2: 1.03255
# [384]	training's rmse: 1.07322	training's l2: 1.1518	valid_1's rmse: 1.01585	valid_1's l2: 1.03195
# [385]	training's rmse: 1.07273	training's l2: 1.15076	valid_1's rmse: 1.01567	valid_1's l2: 1.03158
# [386]	training's rmse: 1.07246	training's l2: 1.15017	valid_1's rmse: 1.01556	valid_1's l2: 1.03136
# [387]	training's rmse: 1.07212	training's l2: 1.14944	valid_1's rmse: 1.01526	valid_1's l2: 1.03075
# [388]	training's rmse: 1.07165	training's l2: 1.14843	valid_1's rmse: 1.01487	valid_1's l2: 1.02996
# [389]	training's rmse: 1.07135	training's l2: 1.1478	valid_1's rmse: 1.01445	valid_1's l2: 1.02911
# [390]	training's rmse: 1.07102	training's l2: 1.14708	valid_1's rmse: 1.01418	valid_1's l2: 1.02855
# [391]	training's rmse: 1.0707	training's l2: 1.14641	valid_1's rmse: 1.01386	valid_1's l2: 1.02791
# [392]	training's rmse: 1.07031	training's l2: 1.14557	valid_1's rmse: 1.01345	valid_1's l2: 1.02708
# [393]	training's rmse: 1.07	training's l2: 1.1449	valid_1's rmse: 1.01301	valid_1's l2: 1.02618
# [394]	training's rmse: 1.06967	training's l2: 1.1442	valid_1's rmse: 1.01263	valid_1's l2: 1.02542
# [395]	training's rmse: 1.06932	training's l2: 1.14345	valid_1's rmse: 1.01236	valid_1's l2: 1.02487
# [396]	training's rmse: 1.06904	training's l2: 1.14286	valid_1's rmse: 1.01181	valid_1's l2: 1.02377
# [397]	training's rmse: 1.06875	training's l2: 1.14222	valid_1's rmse: 1.01159	valid_1's l2: 1.02332
# [398]	training's rmse: 1.06842	training's l2: 1.14152	valid_1's rmse: 1.01125	valid_1's l2: 1.02262
# [399]	training's rmse: 1.06806	training's l2: 1.14074	valid_1's rmse: 1.01096	valid_1's l2: 1.02205
# [400]	training's rmse: 1.06766	training's l2: 1.13989	valid_1's rmse: 1.01056	valid_1's l2: 1.02123
# [401]	training's rmse: 1.06727	training's l2: 1.13906	valid_1's rmse: 1.01018	valid_1's l2: 1.02046
# [402]	training's rmse: 1.067	training's l2: 1.13848	valid_1's rmse: 1.00989	valid_1's l2: 1.01989
# [403]	training's rmse: 1.06659	training's l2: 1.13761	valid_1's rmse: 1.00954	valid_1's l2: 1.01918
# [404]	training's rmse: 1.0661	training's l2: 1.13657	valid_1's rmse: 1.00897	valid_1's l2: 1.01802
# [405]	training's rmse: 1.06582	training's l2: 1.13598	valid_1's rmse: 1.00874	valid_1's l2: 1.01755
# [406]	training's rmse: 1.0655	training's l2: 1.13528	valid_1's rmse: 1.00845	valid_1's l2: 1.01697
# [407]	training's rmse: 1.06526	training's l2: 1.13477	valid_1's rmse: 1.00817	valid_1's l2: 1.01641
# [408]	training's rmse: 1.06503	training's l2: 1.1343	valid_1's rmse: 1.00793	valid_1's l2: 1.01592
# [409]	training's rmse: 1.06467	training's l2: 1.13353	valid_1's rmse: 1.0077	valid_1's l2: 1.01547
# [410]	training's rmse: 1.06442	training's l2: 1.13298	valid_1's rmse: 1.00736	valid_1's l2: 1.01478
# [411]	training's rmse: 1.06414	training's l2: 1.13239	valid_1's rmse: 1.00707	valid_1's l2: 1.01418
# [412]	training's rmse: 1.06392	training's l2: 1.13193	valid_1's rmse: 1.00692	valid_1's l2: 1.01388
# [413]	training's rmse: 1.06366	training's l2: 1.13137	valid_1's rmse: 1.00662	valid_1's l2: 1.01327
# [414]	training's rmse: 1.0633	training's l2: 1.13061	valid_1's rmse: 1.00626	valid_1's l2: 1.01256
# [415]	training's rmse: 1.06292	training's l2: 1.1298	valid_1's rmse: 1.00587	valid_1's l2: 1.01176
# [416]	training's rmse: 1.06259	training's l2: 1.12909	valid_1's rmse: 1.00557	valid_1's l2: 1.01118
# [417]	training's rmse: 1.06232	training's l2: 1.12851	valid_1's rmse: 1.00536	valid_1's l2: 1.01075
# [418]	training's rmse: 1.06196	training's l2: 1.12775	valid_1's rmse: 1.00503	valid_1's l2: 1.01008
# [419]	training's rmse: 1.06169	training's l2: 1.12718	valid_1's rmse: 1.00483	valid_1's l2: 1.00968
# [420]	training's rmse: 1.06138	training's l2: 1.12653	valid_1's rmse: 1.00462	valid_1's l2: 1.00926
# [421]	training's rmse: 1.06117	training's l2: 1.12607	valid_1's rmse: 1.00437	valid_1's l2: 1.00875
# [422]	training's rmse: 1.06086	training's l2: 1.12542	valid_1's rmse: 1.00408	valid_1's l2: 1.00817
# [423]	training's rmse: 1.0606	training's l2: 1.12487	valid_1's rmse: 1.00386	valid_1's l2: 1.00774
# [424]	training's rmse: 1.06019	training's l2: 1.124	valid_1's rmse: 1.00345	valid_1's l2: 1.0069
# [425]	training's rmse: 1.06	training's l2: 1.12359	valid_1's rmse: 1.00326	valid_1's l2: 1.00654
# [426]	training's rmse: 1.05955	training's l2: 1.12265	valid_1's rmse: 1.00281	valid_1's l2: 1.00563
# [427]	training's rmse: 1.05922	training's l2: 1.12195	valid_1's rmse: 1.00252	valid_1's l2: 1.00504
# [428]	training's rmse: 1.05901	training's l2: 1.12151	valid_1's rmse: 1.00235	valid_1's l2: 1.0047
# [429]	training's rmse: 1.05868	training's l2: 1.12079	valid_1's rmse: 1.00194	valid_1's l2: 1.00388
# [430]	training's rmse: 1.05838	training's l2: 1.12017	valid_1's rmse: 1.00169	valid_1's l2: 1.00339
# [431]	training's rmse: 1.05815	training's l2: 1.11968	valid_1's rmse: 1.00149	valid_1's l2: 1.00298
# [432]	training's rmse: 1.05784	training's l2: 1.11902	valid_1's rmse: 1.00119	valid_1's l2: 1.00238
# [433]	training's rmse: 1.05763	training's l2: 1.11858	valid_1's rmse: 1.00093	valid_1's l2: 1.00187
# [434]	training's rmse: 1.05735	training's l2: 1.11799	valid_1's rmse: 1.00073	valid_1's l2: 1.00146
# [435]	training's rmse: 1.05716	training's l2: 1.11759	valid_1's rmse: 1.0005	valid_1's l2: 1.00101
# [436]	training's rmse: 1.05688	training's l2: 1.117	valid_1's rmse: 1.00016	valid_1's l2: 1.00031
# [437]	training's rmse: 1.05662	training's l2: 1.11644	valid_1's rmse: 1.00005	valid_1's l2: 1.0001
# [438]	training's rmse: 1.05636	training's l2: 1.1159	valid_1's rmse: 0.999782	valid_1's l2: 0.999564
# [439]	training's rmse: 1.05616	training's l2: 1.11548	valid_1's rmse: 0.999388	valid_1's l2: 0.998777
# [440]	training's rmse: 1.05594	training's l2: 1.115	valid_1's rmse: 0.99909	valid_1's l2: 0.99818
# [441]	training's rmse: 1.05559	training's l2: 1.11427	valid_1's rmse: 0.998668	valid_1's l2: 0.997338
# [442]	training's rmse: 1.05541	training's l2: 1.11389	valid_1's rmse: 0.998503	valid_1's l2: 0.997008
# [443]	training's rmse: 1.05513	training's l2: 1.1133	valid_1's rmse: 0.998212	valid_1's l2: 0.996428
# [444]	training's rmse: 1.05489	training's l2: 1.1128	valid_1's rmse: 0.997977	valid_1's l2: 0.995958
# [445]	training's rmse: 1.05471	training's l2: 1.11242	valid_1's rmse: 0.997825	valid_1's l2: 0.995654
# [446]	training's rmse: 1.05445	training's l2: 1.11186	valid_1's rmse: 0.997578	valid_1's l2: 0.995161
# [447]	training's rmse: 1.0542	training's l2: 1.11133	valid_1's rmse: 0.997205	valid_1's l2: 0.994417
# [448]	training's rmse: 1.05394	training's l2: 1.11079	valid_1's rmse: 0.996955	valid_1's l2: 0.99392
# [449]	training's rmse: 1.05377	training's l2: 1.11042	valid_1's rmse: 0.99686	valid_1's l2: 0.99373
# [450]	training's rmse: 1.05356	training's l2: 1.10999	valid_1's rmse: 0.996695	valid_1's l2: 0.993402
# [451]	training's rmse: 1.05331	training's l2: 1.10947	valid_1's rmse: 0.996525	valid_1's l2: 0.993061
# [452]	training's rmse: 1.05305	training's l2: 1.10892	valid_1's rmse: 0.996242	valid_1's l2: 0.992498
# [453]	training's rmse: 1.05289	training's l2: 1.10857	valid_1's rmse: 0.996097	valid_1's l2: 0.992209
# [454]	training's rmse: 1.05265	training's l2: 1.10807	valid_1's rmse: 0.995815	valid_1's l2: 0.991647
# [455]	training's rmse: 1.05245	training's l2: 1.10765	valid_1's rmse: 0.995561	valid_1's l2: 0.991141
# [456]	training's rmse: 1.05226	training's l2: 1.10725	valid_1's rmse: 0.995372	valid_1's l2: 0.990766
# [457]	training's rmse: 1.05203	training's l2: 1.10676	valid_1's rmse: 0.995202	valid_1's l2: 0.990428
# [458]	training's rmse: 1.05187	training's l2: 1.10643	valid_1's rmse: 0.995066	valid_1's l2: 0.990156
# [459]	training's rmse: 1.05164	training's l2: 1.10595	valid_1's rmse: 0.994885	valid_1's l2: 0.989796
# [460]	training's rmse: 1.05144	training's l2: 1.10552	valid_1's rmse: 0.994709	valid_1's l2: 0.989447
# [461]	training's rmse: 1.05121	training's l2: 1.10503	valid_1's rmse: 0.994481	valid_1's l2: 0.988993
# [462]	training's rmse: 1.05101	training's l2: 1.10463	valid_1's rmse: 0.994244	valid_1's l2: 0.988521
# [463]	training's rmse: 1.05082	training's l2: 1.10422	valid_1's rmse: 0.99404	valid_1's l2: 0.988115
# [464]	training's rmse: 1.05062	training's l2: 1.10381	valid_1's rmse: 0.993647	valid_1's l2: 0.987334
# [465]	training's rmse: 1.05039	training's l2: 1.10333	valid_1's rmse: 0.993353	valid_1's l2: 0.98675
# [466]	training's rmse: 1.05023	training's l2: 1.10298	valid_1's rmse: 0.993266	valid_1's l2: 0.986578
# [467]	training's rmse: 1.04992	training's l2: 1.10233	valid_1's rmse: 0.992872	valid_1's l2: 0.985795
# [468]	training's rmse: 1.04974	training's l2: 1.10196	valid_1's rmse: 0.992725	valid_1's l2: 0.985503
# [469]	training's rmse: 1.04955	training's l2: 1.10156	valid_1's rmse: 0.992598	valid_1's l2: 0.985251
# [470]	training's rmse: 1.04937	training's l2: 1.10117	valid_1's rmse: 0.992386	valid_1's l2: 0.98483
# [471]	training's rmse: 1.04923	training's l2: 1.10088	valid_1's rmse: 0.992296	valid_1's l2: 0.984652
# [472]	training's rmse: 1.049	training's l2: 1.1004	valid_1's rmse: 0.992078	valid_1's l2: 0.984219
# [473]	training's rmse: 1.04876	training's l2: 1.0999	valid_1's rmse: 0.99174	valid_1's l2: 0.983549
# [474]	training's rmse: 1.04854	training's l2: 1.09943	valid_1's rmse: 0.991469	valid_1's l2: 0.983011
# [475]	training's rmse: 1.04835	training's l2: 1.09903	valid_1's rmse: 0.991311	valid_1's l2: 0.982697
# [476]	training's rmse: 1.04803	training's l2: 1.09836	valid_1's rmse: 0.990995	valid_1's l2: 0.982072
# [477]	training's rmse: 1.04789	training's l2: 1.09808	valid_1's rmse: 0.990908	valid_1's l2: 0.981898
# [478]	training's rmse: 1.04767	training's l2: 1.09762	valid_1's rmse: 0.990635	valid_1's l2: 0.981358
# [479]	training's rmse: 1.04755	training's l2: 1.09735	valid_1's rmse: 0.990445	valid_1's l2: 0.980982
# [480]	training's rmse: 1.04737	training's l2: 1.09698	valid_1's rmse: 0.990195	valid_1's l2: 0.980486
# [481]	training's rmse: 1.04716	training's l2: 1.09653	valid_1's rmse: 0.990031	valid_1's l2: 0.980162
# [482]	training's rmse: 1.04702	training's l2: 1.09625	valid_1's rmse: 0.989933	valid_1's l2: 0.979967
# ...
# [6072]	training's rmse: 0.782083	training's l2: 0.611654	valid_1's rmse: 0.921872	valid_1's l2: 0.849848
# [6073]	training's rmse: 0.782059	training's l2: 0.611616	valid_1's rmse: 0.92189	valid_1's l2: 0.849881
# [6074]	training's rmse: 0.782037	training's l2: 0.611582	valid_1's rmse: 0.921904	valid_1's l2: 0.849907
# [6075]	training's rmse: 0.782023	training's l2: 0.61156	valid_1's rmse: 0.921907	valid_1's l2: 0.849912
# [6076]	training's rmse: 0.782002	training's l2: 0.611527	valid_1's rmse: 0.921911	valid_1's l2: 0.849919
# [6077]	training's rmse: 0.781991	training's l2: 0.611509	valid_1's rmse: 0.921894	valid_1's l2: 0.849888
# [6078]	training's rmse: 0.781931	training's l2: 0.611417	valid_1's rmse: 0.921898	valid_1's l2: 0.849897
# [6079]	training's rmse: 0.781907	training's l2: 0.611379	valid_1's rmse: 0.921907	valid_1's l2: 0.849912
# [6080]	training's rmse: 0.781859	training's l2: 0.611303	valid_1's rmse: 0.921918	valid_1's l2: 0.849933
# [6081]	training's rmse: 0.78184	training's l2: 0.611274	valid_1's rmse: 0.921923	valid_1's l2: 0.849942
# [6082]	training's rmse: 0.78183	training's l2: 0.611259	valid_1's rmse: 0.921925	valid_1's l2: 0.849945
# [6083]	training's rmse: 0.781802	training's l2: 0.611214	valid_1's rmse: 0.921943	valid_1's l2: 0.849978
# [6084]	training's rmse: 0.781776	training's l2: 0.611174	valid_1's rmse: 0.921937	valid_1's l2: 0.849967
# [6085]	training's rmse: 0.781711	training's l2: 0.611073	valid_1's rmse: 0.921937	valid_1's l2: 0.849967
# [6086]	training's rmse: 0.781668	training's l2: 0.611005	valid_1's rmse: 0.921925	valid_1's l2: 0.849946
# [6087]	training's rmse: 0.781633	training's l2: 0.61095	valid_1's rmse: 0.921923	valid_1's l2: 0.849942
# [6088]	training's rmse: 0.78161	training's l2: 0.610914	valid_1's rmse: 0.921906	valid_1's l2: 0.849911
# [6089]	training's rmse: 0.7816	training's l2: 0.610899	valid_1's rmse: 0.921912	valid_1's l2: 0.849922
# [6090]	training's rmse: 0.781583	training's l2: 0.610872	valid_1's rmse: 0.921939	valid_1's l2: 0.849972
# [6091]	training's rmse: 0.781555	training's l2: 0.610827	valid_1's rmse: 0.921937	valid_1's l2: 0.849967
# [6092]	training's rmse: 0.781548	training's l2: 0.610817	valid_1's rmse: 0.921937	valid_1's l2: 0.849967
# [6093]	training's rmse: 0.781522	training's l2: 0.610777	valid_1's rmse: 0.921937	valid_1's l2: 0.849968
# [6094]	training's rmse: 0.781507	training's l2: 0.610753	valid_1's rmse: 0.921925	valid_1's l2: 0.849946
# [6095]	training's rmse: 0.781495	training's l2: 0.610734	valid_1's rmse: 0.921928	valid_1's l2: 0.849951
# [6096]	training's rmse: 0.781464	training's l2: 0.610686	valid_1's rmse: 0.921925	valid_1's l2: 0.849946
# [6097]	training's rmse: 0.781447	training's l2: 0.610659	valid_1's rmse: 0.921911	valid_1's l2: 0.84992
# [6098]	training's rmse: 0.781434	training's l2: 0.610639	valid_1's rmse: 0.92191	valid_1's l2: 0.849917
# [6099]	training's rmse: 0.781416	training's l2: 0.610611	valid_1's rmse: 0.921911	valid_1's l2: 0.84992
# [6100]	training's rmse: 0.781391	training's l2: 0.610572	valid_1's rmse: 0.921907	valid_1's l2: 0.849913
# [6101]	training's rmse: 0.781378	training's l2: 0.610552	valid_1's rmse: 0.92193	valid_1's l2: 0.849956
# [6102]	training's rmse: 0.781349	training's l2: 0.610506	valid_1's rmse: 0.921927	valid_1's l2: 0.84995
# [6103]	training's rmse: 0.781343	training's l2: 0.610497	valid_1's rmse: 0.921925	valid_1's l2: 0.849945
# [6104]	training's rmse: 0.78132	training's l2: 0.610461	valid_1's rmse: 0.921934	valid_1's l2: 0.849963
# [6105]	training's rmse: 0.78128	training's l2: 0.610399	valid_1's rmse: 0.921931	valid_1's l2: 0.849957
# [6106]	training's rmse: 0.781272	training's l2: 0.610386	valid_1's rmse: 0.921927	valid_1's l2: 0.84995
# [6107]	training's rmse: 0.781254	training's l2: 0.610357	valid_1's rmse: 0.921917	valid_1's l2: 0.849931
# [6108]	training's rmse: 0.781235	training's l2: 0.610329	valid_1's rmse: 0.921911	valid_1's l2: 0.84992
# [6109]	training's rmse: 0.78121	training's l2: 0.610289	valid_1's rmse: 0.921915	valid_1's l2: 0.849927
# [6110]	training's rmse: 0.781194	training's l2: 0.610264	valid_1's rmse: 0.921905	valid_1's l2: 0.849909
# [6111]	training's rmse: 0.781153	training's l2: 0.610199	valid_1's rmse: 0.921905	valid_1's l2: 0.84991
# [6112]	training's rmse: 0.781123	training's l2: 0.610153	valid_1's rmse: 0.921894	valid_1's l2: 0.849889
# [6113]	training's rmse: 0.781118	training's l2: 0.610146	valid_1's rmse: 0.921891	valid_1's l2: 0.849883
# [6114]	training's rmse: 0.781103	training's l2: 0.610122	valid_1's rmse: 0.921897	valid_1's l2: 0.849894
# [6115]	training's rmse: 0.781098	training's l2: 0.610114	valid_1's rmse: 0.921894	valid_1's l2: 0.849889
# [6116]	training's rmse: 0.781081	training's l2: 0.610088	valid_1's rmse: 0.921875	valid_1's l2: 0.849853
# [6117]	training's rmse: 0.78106	training's l2: 0.610055	valid_1's rmse: 0.921873	valid_1's l2: 0.84985
# [6118]	training's rmse: 0.781056	training's l2: 0.610049	valid_1's rmse: 0.921872	valid_1's l2: 0.849848
# [6119]	training's rmse: 0.781012	training's l2: 0.60998	valid_1's rmse: 0.921882	valid_1's l2: 0.849867
# [6120]	training's rmse: 0.780991	training's l2: 0.609947	valid_1's rmse: 0.921875	valid_1's l2: 0.849854
# [6121]	training's rmse: 0.780972	training's l2: 0.609917	valid_1's rmse: 0.921862	valid_1's l2: 0.849829
# [6122]	training's rmse: 0.780951	training's l2: 0.609884	valid_1's rmse: 0.921843	valid_1's l2: 0.849794
# [6123]	training's rmse: 0.780932	training's l2: 0.609855	valid_1's rmse: 0.921838	valid_1's l2: 0.849786
# [6124]	training's rmse: 0.780901	training's l2: 0.609806	valid_1's rmse: 0.921826	valid_1's l2: 0.849763
# [6125]	training's rmse: 0.78088	training's l2: 0.609773	valid_1's rmse: 0.921843	valid_1's l2: 0.849794
# [6126]	training's rmse: 0.780875	training's l2: 0.609765	valid_1's rmse: 0.921841	valid_1's l2: 0.849791
# [6127]	training's rmse: 0.780846	training's l2: 0.609721	valid_1's rmse: 0.921839	valid_1's l2: 0.849788
# [6128]	training's rmse: 0.780829	training's l2: 0.609693	valid_1's rmse: 0.921832	valid_1's l2: 0.849775
# [6129]	training's rmse: 0.780806	training's l2: 0.609658	valid_1's rmse: 0.921843	valid_1's l2: 0.849795
# [6130]	training's rmse: 0.780788	training's l2: 0.60963	valid_1's rmse: 0.921847	valid_1's l2: 0.849803
# [6157]	training's rmse: 0.780253	training's l2: 0.608794	valid_1's rmse: 0.921882	valid_1's l2: 0.849867
# [6158]	training's rmse: 0.780235	training's l2: 0.608767	valid_1's rmse: 0.921889	valid_1's l2: 0.84988
# [6159]	training's rmse: 0.780223	training's l2: 0.608748	valid_1's rmse: 0.921883	valid_1's l2: 0.849868
# [6160]	training's rmse: 0.780202	training's l2: 0.608715	valid_1's rmse: 0.921892	valid_1's l2: 0.849885
# [6161]	training's rmse: 0.780176	training's l2: 0.608674	valid_1's rmse: 0.921904	valid_1's l2: 0.849906
# [6162]	training's rmse: 0.780159	training's l2: 0.608649	valid_1's rmse: 0.921897	valid_1's l2: 0.849893
# [6163]	training's rmse: 0.780113	training's l2: 0.608576	valid_1's rmse: 0.921872	valid_1's l2: 0.849849
# [6164]	training's rmse: 0.780106	training's l2: 0.608565	valid_1's rmse: 0.92187	valid_1's l2: 0.849844
# [6165]	training's rmse: 0.780071	training's l2: 0.608511	valid_1's rmse: 0.921879	valid_1's l2: 0.84986
# [6166]	training's rmse: 0.78006	training's l2: 0.608494	valid_1's rmse: 0.92187	valid_1's l2: 0.849845
# [6167]	training's rmse: 0.780043	training's l2: 0.608467	valid_1's rmse: 0.921871	valid_1's l2: 0.849847
# [6168]	training's rmse: 0.779986	training's l2: 0.608378	valid_1's rmse: 0.921874	valid_1's l2: 0.849852
# [6169]	training's rmse: 0.779973	training's l2: 0.608358	valid_1's rmse: 0.92189	valid_1's l2: 0.849882
# [6170]	training's rmse: 0.779957	training's l2: 0.608333	valid_1's rmse: 0.921887	valid_1's l2: 0.849876
# [6171]	training's rmse: 0.779944	training's l2: 0.608313	valid_1's rmse: 0.921896	valid_1's l2: 0.849892
# [6172]	training's rmse: 0.779923	training's l2: 0.60828	valid_1's rmse: 0.921887	valid_1's l2: 0.849876
# [6173]	training's rmse: 0.779918	training's l2: 0.608272	valid_1's rmse: 0.921887	valid_1's l2: 0.849875
# [6174]	training's rmse: 0.77988	training's l2: 0.608213	valid_1's rmse: 0.921898	valid_1's l2: 0.849896
# [6175]	training's rmse: 0.779817	training's l2: 0.608114	valid_1's rmse: 0.921959	valid_1's l2: 0.850007
# [6176]	training's rmse: 0.779775	training's l2: 0.60805	valid_1's rmse: 0.921906	valid_1's l2: 0.84991
# [6177]	training's rmse: 0.77975	training's l2: 0.608011	valid_1's rmse: 0.921904	valid_1's l2: 0.849907
# [6178]	training's rmse: 0.779718	training's l2: 0.607961	valid_1's rmse: 0.921901	valid_1's l2: 0.849901
# [6179]	training's rmse: 0.779696	training's l2: 0.607925	valid_1's rmse: 0.921885	valid_1's l2: 0.849872
# [6180]	training's rmse: 0.779678	training's l2: 0.607898	valid_1's rmse: 0.921874	valid_1's l2: 0.849851
# [6181]	training's rmse: 0.779674	training's l2: 0.607892	valid_1's rmse: 0.921868	valid_1's l2: 0.84984
# [6182]	training's rmse: 0.779649	training's l2: 0.607853	valid_1's rmse: 0.92187	valid_1's l2: 0.849844
# [6210]	training's rmse: 0.779054	training's l2: 0.606925	valid_1's rmse: 0.921867	valid_1's l2: 0.849839
# [6211]	training's rmse: 0.77904	training's l2: 0.606903	valid_1's rmse: 0.921864	valid_1's l2: 0.849834
# [6212]	training's rmse: 0.779031	training's l2: 0.60689	valid_1's rmse: 0.921859	valid_1's l2: 0.849823
# [6213]	training's rmse: 0.779017	training's l2: 0.606868	valid_1's rmse: 0.921855	valid_1's l2: 0.849816
# [6214]	training's rmse: 0.77899	training's l2: 0.606826	valid_1's rmse: 0.921859	valid_1's l2: 0.849823
# [6215]	training's rmse: 0.778987	training's l2: 0.60682	valid_1's rmse: 0.921853	valid_1's l2: 0.849813
# [6216]	training's rmse: 0.778939	training's l2: 0.606746	valid_1's rmse: 0.921844	valid_1's l2: 0.849797
# [6217]	training's rmse: 0.778913	training's l2: 0.606706	valid_1's rmse: 0.921848	valid_1's l2: 0.849804
# [6218]	training's rmse: 0.778901	training's l2: 0.606686	valid_1's rmse: 0.921869	valid_1's l2: 0.849842
# [6219]	training's rmse: 0.778876	training's l2: 0.606647	valid_1's rmse: 0.921866	valid_1's l2: 0.849836
# [6220]	training's rmse: 0.778831	training's l2: 0.606577	valid_1's rmse: 0.921856	valid_1's l2: 0.849818
# [6221]	training's rmse: 0.778818	training's l2: 0.606557	valid_1's rmse: 0.921872	valid_1's l2: 0.849848
# [6222]	training's rmse: 0.778786	training's l2: 0.606507	valid_1's rmse: 0.921855	valid_1's l2: 0.849817
# [6223]	training's rmse: 0.778759	training's l2: 0.606465	valid_1's rmse: 0.921858	valid_1's l2: 0.849822
# datetime.timedelta(seconds=498, microseconds=684707)

# %%
feature_imp
# Out:
#      Value                              Feature
# 0   184122              item_id_city_mean_sales
# 1   124402  shop_id_item_category_id_mean_sales
# 2   121778                   item_id_mean_sales
# 3   113986                              shop_id
# 4   108429                   shop_id_mean_sales
# 5    77829      shop_id_subtype_code_mean_sales
# 6    76257          item_category_id_mean_sales
# 7    71730                              item_id
# 8    58144                           item_price
# 9    36230            duration_after_first_sale
# 10   34764                       date_block_num
# 11   32238                      first_sale_date
# 12   30573                     item_category_id
# 13   25032                         subtype_code
# 14   18930                                month
# 15    8616                                 city
# 16    3539                            type_code

# %%
feature_imp= pd.DataFrame(sorted(zip(lgbm.feature_importances_, X_train.columns), reverse = True), columns = ['Value', 'Feature'])
# feature_imp.to_excel("feature_imp.xlsx")

plt.figure(figsize=(7,5))
sns.barplot(x='Value', y='Feature', data=feature_imp[:10].sort_values(by='Value', ascending=False))
plt.tight_layout()
plt.show()
plt.savefig('lightGBM_ Importances.png')

# %% [markdown]
# # 3. Modeling

# %%
sales_prediction = model_lgb.predict(test)
test = pd.read_csv("data/test.csv")
test_result= pd.DataFrame(sales_prediction)
test_result.columns = ['item_cnt_month']
predict = test_result['item_cnt_month']
sales_predict_submission = pd.DataFrame({'ID':test['ID'],'item_cnt_month':predict})
sales_predict_submission.to_csv('submission.csv', index=False)
